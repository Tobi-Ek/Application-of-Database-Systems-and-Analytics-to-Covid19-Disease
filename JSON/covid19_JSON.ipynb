# %%
import OpenBlender
import pandas as pd
import json


action = 'API_getObservationsFromDataset'

# ANCHOR: 'COVID19 Confirmed Cases'

        
parameters = { 
    	'token':'5e7931479516291997070c75iSofZhsdyQcp1yXw1VkC8frwTxYgZH',
	'id_user':'5e7931479516291997070c75',
	'id_dataset':'5e6ac97595162921fda18076' 
}
        

df = pd.read_json(json.dumps(OpenBlender.call(action, parameters)['sample']), convert_dates=False, convert_axes=False).sort_values('timestamp', ascending=False)
df1=df.copy()
df.reset_index(drop=True, inplace=True)
df.head()
# Out:
# Task ID: '5e7932150895fafb4a9d8d4b'.
# Total estimated consumption: 52522.48 processing units.
# Task confirmed. Starting download..
# 6.67 %
# 13.33 %
# 20.0 %
# 26.67 %
# 33.33 %
# 40.0 %
# 46.67 %
# 53.33 %
# 60.0 %
# 66.67 %
# 73.33 %
# 80.0 %
# 86.67 %
# 93.33 %
# 100.0 % completed.
#   confirmed deaths   timestamp provincestate longitude latitude recovered  \
# 0         1      0  1584920583                 -61.679  12.1165         0
# 1       134      2  1584920583                -83.7534   9.7489         2
# 2       789     14  1584920583                -78.1834  -1.8312         3
# 3       425      5  1584920583       Ontario  -85.3232  51.2538         6
# 4       327     14  1584920583                 30.8025  26.8206        56
#
#   countryregion
# 0       Grenada
# 1    Costa Rica
# 2       Ecuador
# 3        Canada
# 4         Egypt

# %%
df1
# Out:
#      confirmed deaths   timestamp provincestate longitude latitude recovered  \
# 0            1      0  1584920583                 -61.679  12.1165         0
# 10         134      2  1584920583                -83.7534   9.7489         2
# 17         789     14  1584920583                -78.1834  -1.8312         3
# 16         425      5  1584920583       Ontario  -85.3232  51.2538         6
# 15         327     14  1584920583                 30.8025  26.8206        56
# ...        ...    ...         ...           ...       ...      ...       ...
# 8412                   1579687200         Tibet
# 8413         1         1579687200        Fujian
# 8414         4         1579687200       Tianjin
# 8415         1         1579687200        Taiwan
# 8436         1         1579687200         Anhui
#
#        countryregion
# 0            Grenada
# 10        Costa Rica
# 17           Ecuador
# 16            Canada
# 15             Egypt
# ...              ...
# 8412  Mainland China
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8437 entries, 0 to 8436
# Data columns (total 8 columns):
# confirmed        8437 non-null object
# deaths           8437 non-null object
# timestamp        8437 non-null int64
# provincestate    8437 non-null object
# longitude        8437 non-null object
# latitude         8437 non-null object
# recovered        8437 non-null object
# countryregion    8437 non-null object
# dtypes: int64(1), object(7)
# memory usage: 527.4+ KB

# %% [markdown]
# ## COVID 19 action

# %%
import requests
from bs4 import BeautifulSoup

# %%
URL="https://www.gov.je/Datasets/ListOpenData?ListName=COVID19&type=json"
page=requests.get(URL)
soup=BeautifulSoup(page.content,'html.parser')

# %%
soup.get('COVID19')
data=str(soup)

# %%
import json
d=json.loads(data)
d['COVID19']
# Out:
# [{'Date': '2020-04-21',
#   'Negativetests': '1919',
#   'Confirmedcases': '255',
#   'Pendingresults': '46',
#   'Deaths': '14',
#   'Recovered': '133',
#   'Totalsamplestested': '2220',
#   'Totalpeopletested': '2058',
#   'Totalresultsback': '2174',
#   'Femalepositivepercentage': '58',
#   'Malepositivepercentage': '42',
#   'Averageagetestedpositive': '54',
#   'Femalerecoveredpercentage': '56',
#   'Malerecoveredpercentage': '44',
#   'Averageagerecovered': '46',
#   'Numberofhospitalbedsoccupied': '68',
#   'Numberofhospitalbedsavailable': '129',
#   'Hospitaloccupancyratepercentage': '35',
#   'NumberofpatientswithCovid-19inhospital': '14',
#   'DateTime': 'string;#2:55 PM, Tuesday 21 April 2020',
#   'Note': ''},
#  {'Date': '2020-04-20',
#   'Negativetests': '1880',
#   'Confirmedcases': '250',
#   'Pendingresults': '2',
#   'Deaths': '14',
#   'Recovered': '118',
#   'Totalsamplestested': '2132',
#   'Totalpeopletested': '1976',
#   'Totalresultsback': '2130',
# ...

# %%
from pandas.io.json import json_normalize
import pandas as pd

# %%
df = pd.DataFrame.from_dict(json_normalize(d['COVID19']), orient='columns')
# Out:
# /Users/rahul/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.

# %%
df.head()
# Out:
#          Date Negativetests Confirmedcases Pendingresults  \
# 0  2020-03-23           405             16             78
# 1  2020-03-21           383             15             89
# 2  2020-03-20           372             12             38
# 3  2020-03-19           323             10             87
# 4  2020-03-18           293              6
#
#                                    DateTime
# 0     string;#2:30 PM, Monday 23 March 2020
# 1   string;#5:00 PM, Saturday 21 March 2020
# 2     string;#2:30 PM, Friday 20 March 2020
# 3   string;#5:00 PM, Thursday 19 March 2020
# 4  string;#2:30 PM, Wednesday 18 March 2020
